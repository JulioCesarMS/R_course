# %% [markdown]
# <a href="https://colab.research.google.com/github/JulioCesarMS/R_course/blob/master/7.-%20Manipulaci%C3%B3n%20de%20datos%20II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> **Manipulación de datos II**

# %% [markdown]
# # **group_by() y summarize()**

# %% [markdown]
# > **group_by(data, ...)** Sirve para agrupar filas (filas) de un data frame para obtener variables de resumen.
#
# **Argumentos:**
#
# - **data** : dataframe
# - ...  : variable o grupo de variables a ser agrupadas.

# %% [markdown]
# ![groupby.png](data:image/png;base64,...)

# %% [markdown]
#  Después de aplicar la función group_by() es necesario aplicar una función resumen como summarize().
#
# > **summarize()** : Sirve para obtener resumen de variables, dentro de esta podemos especifícar funciones resumen como :
# > - sum()
# > - mean()
# > - sd()
# > - var()
# > - max()
# > - min()
# > - n()
# > - n_distinct()
# > - first()
# > - last()
#
#
# > **ungroup()** : sirve para desagrupar, es conveniente desagrupar cuando se requiera hacer calculos con valores de variables desagrupados.

# %%
library('dplyr')

# %% [markdown]
# Vamos a continuar con el dataset de **starwars**

# %%
head(starwars)
# Out:
#   name           height mass hair_color  skin_color  eye_color birth_year
# 1 Luke Skywalker 172     77  blond       fair        blue       19.0
# 2 C-3PO          167     75  NA          gold        yellow    112.0
# 3 R2-D2           96     32  NA          white, blue red        33.0
# 4 Darth Vader    202    136  none        white       yellow     41.9
# 5 Leia Organa    150     49  brown       light       brown      19.0
# 6 Owen Lars      178    120  brown, grey light       blue       52.0
#   sex    gender    homeworld species
# 1 male   masculine Tatooine  Human
# 2 none   masculine Tatooine  Droid
# 3 none   masculine Naboo     Droid
# 4 male   masculine Tatooine  Human
# 5 female feminine  Alderaan  Human
# 6 male   masculine Tatooine  Human
#   films
# 1 The Empire Strikes Back, Revenge of the Sith    , Return of the Jedi     , A New Hope             , The Force Awakens
# ...

# %%
dim(starwars)
# Out:
# [1] 87 14

# %% [markdown]
# Supongamos que deseamos obtener el total de registros de cada categoría de la variable especie.

# %%
df01 <- starwars %>%
  group_by(species) %>%
  summarise('Total'=n()) %>%
  ungroup() %>%
  mutate('Porcentaje' = round(Total/sum(Total),2)) %>%
  arrange(desc(Total))

head(df01)
# Out:
#   species  Total Porcentaje
# 1 Human    35    0.40
# 2 Droid     6    0.07
# 3 NA        4    0.05
# 4 Gungan    3    0.03
# 5 Kaminoan  2    0.02
# 6 Mirialan  2    0.02

# %% [markdown]
# - Deseamos obtener el porcentaje del genero y color de ojos

# %%
# código aquí

# %% [markdown]
# # **pivot_longer()**
#
# > *pivot_longer(data, cols, names_to = "name", values_to = "value", ...)*
#
# - **data** : dataframe
# - **cols** : columnas a formato long
# - **names_to** : Una cadena que especifica la nueva columna.
# - **values_to : Una cadena que especifica el nombre de la columna a crear a partir de los datos almacenados en los valores de las celdas.

# %% [markdown]
# ![pivotlonger.png](data:image/png;base64,...)

# %% [markdown]
# # **pivot_wider()**
#
# > *pivot_wider(data, names_from = "name", values_from = "value", values_fill, ...)*
#
# - **data** : dataframe
# - **names_from** : Una cadena que especifica la nueva columna.
# - **values_from** : Una cadena que especifica el nombre de la columna a crear a partir de los datos almacenados en los valores de las celdas.
# - **values_fill** : (Opcional) Valor que especifica con qué debe rellenarse cada valor faltante.

# %% [markdown]
# ![pivotwider.png](data:image/png;base64,...)<img src="./images/fig06.png">

# %% [markdown]
# # **Joins**
#
# Nos permite combinar filas de dos o más tablas  basándose en una o varias columnas relacionadas entre ellas.
#
# - **inner_join(x, y, by, suffix = c(".x", ".y"), ...)**: incluye todas las filas de $x$ y $y$.
#
# - **left_join(x, y, by, suffix = c(".x", ".y"), ...)**: incluye todas las filas de $x$.
#
# - **right_join(x, y, by, suffix = c(".x", ".y"), ...)**: incluye todas las filas de $y$.
#
# - **full_join(x, y, by, suffix = c(".x", ".y"), ...)**: incluye todas las filas de x o y.

# %% [markdown]
# ![JOIN.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [Visualización interactiva](https://github.com/gadenbuie/tidyexplain/blob/main/images/inner-join.gif)

# %% [markdown]
# #**Caso Práctico : Incidencia delictiva**

# %% [markdown]
# Incidencia delictiva del fuero común a nivel municipal. El dataset contiene $6$ archivos con los años del $2015$ al $2021$, con los siguientes encabezados:
#
# - 'Año'
# - 'Clave_Ent'
# - 'Entidad'
# - 'Cve. Municipio'
# - 'Municipio'
# - 'Bien jurídico afectado'
# - 'Tipo de delito'
# - 'Subtipo de delito'
# - 'Modalidad'
# - 'Enero'
# - 'Febrero'
# - 'Marzo'
# - 'Abril'
# - 'Mayo'
# - 'Junio'
# - 'Julio'
# - 'Agosto'
# - 'Septiembre'
# - 'Octubre'
# - 'Noviembre'
# - 'Diciembre'

# %% [markdown]
# **Fuente** : [Incidencia Delictiva](https://datos.gob.mx/busca/dataset/incidencia-delictiva-del-fuero-comun-a-nivel-municipal)

# %%
library('tidyr')
library('dplyr')

# %%
# download from github
# download.file(url ='https://github.com/JulioCesarMS/R_course/blob/master/datasets/Delitos.zip', destfile = "Delitos.zip")

# %% [markdown]
# Con la función **unzip()** nos ayuda a extrarer los archivos dentro de un .zip.

# %%
unzip(zipfile = "Municipal-Delitos-2015-2021_dic2021.zip")

# %%
df2015 <- read.csv('2015.csv', header=T, fileEncoding = "Latin1", check.names = FALSE)
head(df2015)
# Out:
#   Año  Clave_Ent Entidad        Cve. Municipio Municipio
# 1 2015 1         Aguascalientes 1001           Aguascalientes
# 2 2015 1         Aguascalientes 1001           Aguascalientes
# 3 2015 1         Aguascalientes 1001           Aguascalientes
# 4 2015 1         Aguascalientes 1001           Aguascalientes
# 5 2015 1         Aguascalientes 1001           Aguascalientes
# 6 2015 1         Aguascalientes 1001           Aguascalientes
#   Bien jurídico afectado           Tipo de delito Subtipo de delito
# 1 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 2 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 3 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 4 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 5 La vida y la Integridad corporal Homicidio      Homicidio culposo
# 6 La vida y la Integridad corporal Homicidio      Homicidio culposo
# ...

# %%
dim(df2015)
# Out:
# [1] 189238     21

# %% [markdown]
# ## Lectura de datasets

# %% [markdown]
# Agregamos en una lista todas las bases, del $2015$ al $2021$.

# %%
names <- c('2015', '2016', '2017', '2018', '2019', '2020', '2021')
df_list <- list()
for(i in 1:length(names)){
  df_list[[i]] <- read.csv(paste(names[i], '.csv', sep=''), header=T, fileEncoding = "Latin1", check.names = FALSE)
}

# %% [markdown]
# Con la función $do.call()$ concatenamos por filas todos dataframes en la lista que generamos.

# %%
df_delitos <- do.call("rbind", df_list)

# %% [markdown]
# Verificamos que nuestro dataframe "df_delitos" contenga todos los años.

# %%
unique(df_delitos$Año)
# Out:
# [1] 2015 2016 2017 2018 2019 2020 2021

# %%
head(df_delitos)
# Out:
#   Año  Clave_Ent Entidad        Cve. Municipio Municipio
# 1 2015 1         Aguascalientes 1001           Aguascalientes
# 2 2015 1         Aguascalientes 1001           Aguascalientes
# 3 2015 1         Aguascalientes 1001           Aguascalientes
# 4 2015 1         Aguascalientes 1001           Aguascalientes
# 5 2015 1         Aguascalientes 1001           Aguascalientes
# 6 2015 1         Aguascalientes 1001           Aguascalientes
#   Bien jurídico afectado           Tipo de delito Subtipo de delito
# 1 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 2 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 3 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 4 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 5 La vida y la Integridad corporal Homicidio      Homicidio culposo
# 6 La vida y la Integridad corporal Homicidio      Homicidio culposo
# ...

# %% [markdown]
# Generamos un dataframe con el nombre del mes y su correspondiente número.

# %%
mes <- data.frame('Mes'=c('Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'),
                  'MesNum' = c('01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12'))

# %% [markdown]
# ## Ejercicio 1:
#
# - Con la información deseamos conocer la cantidad de "Homicidios" por entidad federativa

# %%
df_delitos.1 <- df_delitos %>% 
  pivot_longer(Enero:Diciembre, names_to='Mes', values_to='Valor') %>% 
  left_join(mes, by='Mes') %>% 
  mutate('Fecha' = as.Date(paste(Año, MesNum,'01', sep='-'))) %>%
  select(Fecha, everything())%>%
  #select(-Año, -Mes, -MesNum) %>%
  filter(`Tipo de delito`=='Homicidio') %>% # alt 96 (`)
  group_by(Entidad) %>%
  summarise(n = sum(Valor)) %>%
  arrange(desc(n))

df_delitos.1
# Out:
#    Entidad                         n
# 1  Guanajuato                      25741
# 2  México                          23349
# 3  Michoacán de Ocampo             17764
# 4  Baja California                 17659
# 5  Jalisco                         16756
# 6  Guerrero                        16194
# 7  Veracruz de Ignacio de la Llave 14586
# 8  Chihuahua                       14226
# 9  Ciudad de México                12269
# 10 Oaxaca                          10583
# 11 Sinaloa                         10315
# 12 Puebla                          10143
# 13 Tamaulipas                      10086
# 14 Sonora                           9457
# 15 Chiapas                          9081
# 16 Nuevo León                       9031
# 17 Morelos                          7030
# 18 Quintana Roo                     6640
# 19 Tabasco                          5936
# 20 Zacatecas                        5406
# 21 San Luis Potosí                  5176
# 22 Hidalgo                          4452
# ...

# %% [markdown]
# ¿Cúales son los $10$ estados con mayor cantidad de homicidios?

# %%
df_delitos.1 <- df_delitos %>% 
  pivot_longer(Enero:Diciembre, names_to='Mes', values_to='Valor') %>% 
  left_join(mes, by='Mes') %>% 
  mutate('Fecha' = as.Date(paste(Año, MesNum,'01', sep='-'))) %>%
  select(Fecha, everything())%>%
  #select(-Año, -Mes, -MesNum) %>%
  filter(`Tipo de delito`=='Homicidio') %>% # alt 96 (`)
  group_by(Entidad) %>%
  summarise(n = sum(Valor)) %>%
  arrange(desc(n)) %>%
  head(10)

df_delitos.1
# Out:
#    Entidad                         n
# 1  Guanajuato                      25741
# 2  México                          23349
# 3  Michoacán de Ocampo             17764
# 4  Baja California                 17659
# 5  Jalisco                         16756
# 6  Guerrero                        16194
# 7  Veracruz de Ignacio de la Llave 14586
# 8  Chihuahua                       14226
# 9  Ciudad de México                12269
# 10 Oaxaca                          10583

# %% [markdown]
# ¿Cúales son los $10$ estados con menor cantidad de homicidios?

# %%
df_delitos.1 <- df_delitos %>% 
  pivot_longer(Enero:Diciembre, names_to='Mes', values_to='Valor') %>% 
  left_join(mes, by='Mes') %>% 
  mutate('Fecha' = as.Date(paste(Año, MesNum,'01', sep='-'))) %>%
  select(Fecha, everything())%>%
  #select(-Año, -Mes, -MesNum) %>%
  filter(`Tipo de delito`=='Homicidio') %>% # alt 96 (`)
  group_by(Entidad) %>%
  summarise(n = sum(Valor)) %>%
  arrange(desc(n)) %>%
  tail(10)

df_delitos.1
# Out:
#    Entidad              n
# 1  Colima               4389
# 2  Querétaro            3330
# 3  Coahuila de Zaragoza 3166
# 4  Durango              2855
# 5  Nayarit              1919
# 6  Baja California Sur  1816
# 7  Aguascalientes       1696
# 8  Tlaxcala             1673
# 9  Campeche             1010
# 10 Yucatán               904

# %% [markdown]
# ## Ejercicio 2:
#
# - Con la información deseamos conocer la cantidad de "Homicidios" por entidad federativa por año de la siguiente manera:
#
#
# | Entidad  | 2015 | 2016 | 2017 | 2018 | 2019 | 2020 | 2021 |
# | --       | --   |  --  |  --  |  --  |  --  | --   |  --  |
# | Agusacalientes  | -    |  -   | -    | -    |   -  |   -  | - |

# %%
df_delitos.2 <- df_delitos %>% 
  # codigo aquí
  

df_delitos.2
# Out:
# `summarise()` has grouped output by 'Año'. You can override using the `.groups`
# argument.
#    Entidad                         2015 2016 2017 2018 2019 2020 2021
# 1  Guanajuato                      2398 2572 3366 4298 4494 4940 3673
# 2  México                          3097 2899 3248 3339 3472 3575 3719
# 3  Michoacán de Ocampo             2041 2356 2246 2276 2686 2921 3238
# 4  Baja California                 1219 1503 2430 3169 3065 3066 3207
# 5  Guerrero                        2721 2844 2868 2716 2031 1469 1545
# 6  Jalisco                         1736 2027 2109 2762 2753 2626 2743
# 7  Veracruz de Ignacio de la Llave 1008 1817 2688 2439 2393 2178 2063
# 8  Chihuahua                       1286 1547 1908 2087 2449 2565 2384
# 9  Ciudad de México                1585 1594 1816 1981 1997 1761 1535
# 10 Puebla                          1206 1206 1647 1983 1664 1266 1171
# 11 Sonora                           983 1068 1149 1157 1421 1711 1968
# ...

# %% [markdown]
# # Agregando latitud y longitud a nivel municipio

# %% [markdown]
# Para obtener la latitud y longitud de cada colonia en México, existen un [Catálogo Único de Claves de Áreas Geoestadísticas Estatales, Municipales y Localidades](https://www.inegi.org.mx/app/ageeml/), elaborado por el INEGI.

# %%
unzip(zipfile = "AGEEML_2020515349313.zip")

# %%
ag <- read.csv('AGEEML_2020515349313.csv', header=T, fileEncoding = "Latin1", check.names = FALSE) %>% 
  group_by(Cve_Ent, Nom_Ent, Nom_Abr, Cve_Mun,Nom_Mun) %>%
  summarise('Lat'=mean(Lat_Decimal),
            'Lon'=mean(Lon_Decimal)) %>%
  ungroup() %>%
  data.frame()
  
head(ag)
# Out:
# `summarise()` has grouped output by 'Cve_Ent', 'Nom_Ent', 'Nom_Abr', 'Cve_Mun'.
# You can override using the `.groups` argument.
#   Cve_Ent Nom_Ent        Nom_Abr Cve_Mun Nom_Mun             Lat      Lon
# 1 1       Aguascalientes Ags.    1       Aguascalientes      21.83119 -102.2825
# 2 1       Aguascalientes Ags.    2       Asientos            22.14037 -102.0411
# 3 1       Aguascalientes Ags.    3       Calvillo            21.88095 -102.7154
# 4 1       Aguascalientes Ags.    4       Cosío               22.35870 -102.2808
# 5 1       Aguascalientes Ags.    5       Jesús María         21.94707 -102.3868
# 6 1       Aguascalientes Ags.    6       Pabellón de Arteaga 22.11853 -102.2823

# %%
unique(ag$Nom_Ent)
# Out:
#  [1] "Aguascalientes"                  "Baja California"
#  [3] "Baja California Sur"             "Campeche"
#  [5] "Coahuila de Zaragoza"            "Colima"
#  [7] "Chiapas"                         "Chihuahua"
#  [9] "Ciudad de México"                "Durango"
# [11] "Guanajuato"                      "Guerrero"
# [13] "Hidalgo"                         "Jalisco"
# [15] "México"                          "Michoacán de Ocampo"
# [17] "Morelos"                         "Nayarit"
# [19] "Nuevo León"                      "Oaxaca"
# [21] "Puebla"                          "Querétaro"
# [23] "Quintana Roo"                    "San Luis Potosí"
# [25] "Sinaloa"                         "Sonora"
# [27] "Tabasco"                         "Tamaulipas"
# [29] "Tlaxcala"                        "Veracruz de Ignacio de la Llave"
# [31] "Yucatán"                         "Zacatecas"

# %%
head(df_delitos%>%arrange(Entidad, Municipio))
# Out:
#   Año  Clave_Ent Entidad        Cve. Municipio Municipio
# 1 2015 1         Aguascalientes 1001           Aguascalientes
# 2 2015 1         Aguascalientes 1001           Aguascalientes
# 3 2015 1         Aguascalientes 1001           Aguascalientes
# 4 2015 1         Aguascalientes 1001           Aguascalientes
# 5 2015 1         Aguascalientes 1001           Aguascalientes
# 6 2015 1         Aguascalientes 1001           Aguascalientes
#   Bien jurídico afectado           Tipo de delito Subtipo de delito
# 1 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 2 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 3 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 4 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 5 La vida y la Integridad corporal Homicidio      Homicidio culposo
# 6 La vida y la Integridad corporal Homicidio      Homicidio culposo
# ...

# %%
unique(df_delitos$Entidad)
# Out:
#  [1] "Aguascalientes"                  "Baja California"
#  [3] "Baja California Sur"             "Campeche"
#  [5] "Coahuila de Zaragoza"            "Colima"
#  [7] "Chiapas"                         "Chihuahua"
#  [9] "Ciudad de México"                "Durango"
# [11] "Guanajuato"                      "Guerrero"
# [13] "Hidalgo"                         "Jalisco"
# [15] "México"                          "Michoacán de Ocampo"
# [17] "Morelos"                         "Nayarit"
# [19] "Nuevo León"                      "Oaxaca"
# [21] "Puebla"                          "Querétaro"
# [23] "Quintana Roo"                    "San Luis Potosí"
# [25] "Sinaloa"                         "Sonora"
# [27] "Tabasco"                         "Tamaulipas"
# [29] "Tlaxcala"                        "Veracruz de Ignacio de la Llave"
# [31] "Yucatán"                         "Zacatecas"

# %% [markdown]
# # Unión de los datasets

# %%
df_delitos_ll <- df_delitos %>%
  left_join(ag, by=c('Entidad'='Nom_Ent', 'Municipio'='Nom_Mun')) %>%
  #merge(ag, by.x=c('Entidad', 'Municipio'), by.y=c('Nom_Ent', 'Nom_Mun'))
  pivot_longer(Enero:Diciembre, names_to='Mes', values_to='Valor') %>% 
  left_join(mes, by='Mes') %>% 
  mutate('Fecha' = as.Date(paste(Año, MesNum,'01', sep='-'))) %>%
  select(Fecha, everything()) %>%
  filter(`Tipo de delito`=='Homicidio')

head(df_delitos_ll)
# Out:
#   Fecha      Año  Clave_Ent Entidad        Cve. Municipio Municipio
# 1 2015-01-01 2015 1         Aguascalientes 1001           Aguascalientes
# 2 2015-02-01 2015 1         Aguascalientes 1001           Aguascalientes
# 3 2015-03-01 2015 1         Aguascalientes 1001           Aguascalientes
# 4 2015-04-01 2015 1         Aguascalientes 1001           Aguascalientes
# 5 2015-05-01 2015 1         Aguascalientes 1001           Aguascalientes
# 6 2015-06-01 2015 1         Aguascalientes 1001           Aguascalientes
#   Bien jurídico afectado           Tipo de delito Subtipo de delito
# 1 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 2 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 3 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 4 La vida y la Integridad corporal Homicidio      Homicidio doloso
# 5 La vida y la Integridad corporal Homicidio      Homicidio doloso
# ...

# %%
df_map <- df_delitos_ll
# Out:
#      Fecha Año Clave_Ent Entidad Cve. Municipio Municipio
#      Bien jurídico afectado Tipo de delito Subtipo de delito Modalidad Cve_Ent
#      Nom_Abr Cve_Mun Lat Lon Mes Valor MesNum

# %%
#install.packages("leaflet")
#install.packages("htmlwidgets")
#install.packages("IRdisplay")
library("leaflet")
library("htmlwidgets")
library("IRdisplay")

# %%
year = 2019

# %%
df_world <- df_map %>%
    group_by(Año, Entidad, `Tipo de delito`) %>%
    summarise('Valor' = sum(Valor),
              'Lat' = mean(Lat),
              'Lon' = mean(Lon)) %>%
    ungroup() %>%
    mutate(radio = ifelse(Valor<=100,1,
                          ifelse(Valor<=300,5,
                                 ifelse(Valor<=500,10,
                                        ifelse(Valor>500,20,0))))) %>%
    filter(Año==year) %>%
    #filter(Valor >0) %>%
    filter(!is.na(Lon), !is.na(Lat))
# Out:
# `summarise()` has grouped output by 'Año', 'Entidad'. You can override using
# the `.groups` argument.

# %%
plt <- leaflet(df_world) %>% 
    addTiles() %>% 
    addCircleMarkers(
      #clusterOptions = markerClusterOptions(),
      lng = df_world$Lon,
      lat = df_world$Lat,
      radius = df_world$radio,
      color = 'red',
      popup = paste('<b><a>Año :</a></b> ',df_world$Año,"<br/>" ,
                     '<b><a>Entidad :</a></b> ',df_world$Entidad,"<br/>" ,
                     '<b><a>Homicidios Totales:</a></b> ',df_world$Valor,"<br/>")) %>%
    setView(lng = mean(df_world$Lon),lat = mean(df_world$Lat), zoom=5)%>%
    addProviderTiles("Stadia.AlidadeSmoothDark") # Stadia.AlidadeSmoothDark

# %%
saveWidget(plt, 'map.html', selfcontained = TRUE)

# %%
IaminColab<-TRUE

if(IaminColab){  
  demo<-readLines("map.html")
  demo<-gsub("%","%25",demo)
  demo<-gsub("#","%23",demo)
  demo<-gsub("\"","%22",demo)
  demo<-gsub("'" ,"%27",demo)
  demo<-gsub("\\n" ,"", demo)
  demo<-paste(demo, collapse="")
  display_html(paste0('<iframe src=',"\"data:text/html;charset=UTF-8,",demo," \" height=\"500\" width=\"1000\"></iframe>") )
} else { # does not work in colab
  display_html('<iframe src="map.html" width="1800" height ="500"></iframe>')
}
# Out:
# <iframe src="data:text/html;charset=UTF-8,<!DOCTYPE html><html><head><meta charset=%22utf-8%22 /><title>leaflet</title><script src=%22data:application/x-javascript;base64,...%22></script><script src=%22data:application/x-javascript;base64,...%22></script><link href=%22data:text/css;charset=utf-8,%250A%252Eleaflet%252Dpane%252C%250A%252Eleaflet%252Dtile%252C%250A%252Eleaflet%252Dmarker%252Dicon%252C%250A%252Eleaflet%252Dmarker%252Dshadow%252C%250A%252Eleaflet%252Dtile%252Dcontainer%252C%250A%252Eleaflet%252Dpane%2520%253E%2520svg%252C%250A%252Eleaflet%252Dpane%2520%253E%2520canvas%252C%250A%252Eleaflet%252Dzoom%252Dbox%252C%250A%252Eleaflet%252Dimage%252Dlayer%252C%250A%252Eleaflet%252Dlayer%2520%257B%250Aposition%253A%2520absolute%253B%250Aleft%253A%25200%253B%250Atop%253A%25200%253B%250A%257D%250A%252Eleaflet%252Dcontainer%2520%257B%250Aoverflow%253A%2520hidden%253B%250A%257D%250A%252Eleaflet%252Dtile%252C%250A%252Eleaflet%252Dmarker%252Dicon%252C%250A%252Eleaflet%252Dmarker%252Dsha
# ...
